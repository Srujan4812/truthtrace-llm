# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\srujan  R\OneDrive\Desktop\cleaned_news.csv")

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject        date  \
# 0  Donald Trump just couldn t wish all Americans ...    News  2017-12-31
# 1  House Intelligence Committee Chairman Devin Nu...    News  2017-12-31
# 2  On Friday, it was revealed that former Milwauk...    News  2017-12-30
# 3  On Christmas day, Donald Trump announced that ...    News  2017-12-29
# 4  Pope Francis used his annual Christmas Day mes...    News  2017-12-25
#
#   label  text_len  title_len
# 0  fake      2893         79
# 1  fake      1898         69
# 2  fake      3597         90
# 3  fake      2774         78
# 4  fake      2346         70

# %%
df['combined_text'] = df['title'] + df['text']

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject        date  \
# 0  Donald Trump just couldn t wish all Americans ...    News  2017-12-31
# 1  House Intelligence Committee Chairman Devin Nu...    News  2017-12-31
# 2  On Friday, it was revealed that former Milwauk...    News  2017-12-30
# 3  On Christmas day, Donald Trump announced that ...    News  2017-12-29
# 4  Pope Francis used his annual Christmas Day mes...    News  2017-12-25
#
#   label  text_len  title_len  \
# 0  fake      2893         79
# 1  fake      1898         69
# 2  fake      3597         90
# 3  fake      2774         78
# 4  fake      2346         70
#
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=5000)  # limit to top 5000 words
X_tfidf = vectorizer.fit_transform(df['combined_text'])

# %%
X_numeric = df[['text_len', 'title_len']].values

# %%
from scipy.sparse import hstack
X = hstack([X_tfidf, X_numeric])

# %%
y = df['label'].map({'fake': 1, 'real': 0})

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject        date  \
# 0  Donald Trump just couldn t wish all Americans ...    News  2017-12-31
# 1  House Intelligence Committee Chairman Devin Nu...    News  2017-12-31
# 2  On Friday, it was revealed that former Milwauk...    News  2017-12-30
# 3  On Christmas day, Donald Trump announced that ...    News  2017-12-29
# 4  Pope Francis used his annual Christmas Day mes...    News  2017-12-25
#
#   label  text_len  title_len  \
# 0  fake      2893         79
# 1  fake      1898         69
# 2  fake      3597         90
# 3  fake      2774         78
# 4  fake      2346         70
#
# ...

# %%
df['label'] = df['label'].map({'fake': 0, 'real': 1})

# %%
df.drop(columns=['date'], inplace=True)

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  label  text_len  \
# 0  Donald Trump just couldn t wish all Americans ...    News      0      2893
# 1  House Intelligence Committee Chairman Devin Nu...    News      0      1898
# 2  On Friday, it was revealed that former Milwauk...    News      0      3597
# 3  On Christmas day, Donald Trump announced that ...    News      0      2774
# 4  Pope Francis used his annual Christmas Day mes...    News      0      2346
#
#    title_len                                      combined_text
# 0         79   Donald Trump Sends Out Embarrassing New Year’...
# ...

# %%
df.to_csv(r"C:\Users\srujan  R\OneDrive\Desktop\New folder (4)\cleaned_news_dataset.csv", index=False)
